# %% [markdown]
# ## 美团新爬虫研究

# %%
cookies_str = """uuid=47B934BEBAF168E963F01628B06A860E3899EB3D09E8EF959370ACBDE2557E37; iuuid=47B934BEBAF168E963F01628B06A860E3899EB3D09E8EF959370ACBDE2557E37; zgwww=a989df00-b93e-11ee-99b9-37ae6d658dae; WEBDFPID=37u85v1u29015wx212v9u7w5y427u56z81w68w2z1wy97958x8u02yuw-2021298233451-1705938231635CCEMGOE75613c134b6a252faa6802015be905513017; _lxsdk_cuid=18d31d7a129c8-07b49bcf5ffa65-17525635-168000-18d31d7a129c8; _lxsdk=47B934BEBAF168E963F01628B06A860E3899EB3D09E8EF959370ACBDE2557E37; _gid=GA1.2.1650718522.1705938929; zg.userid.untrusted=20834339; token2=AgF-JC16yAvBdTpe-7v7BL4qsJRZeW62XiSIuNkiHGFYZZE_C0DBM_rt4YJq2c6ZO3GvjyF_luJOvgAAAAC3HQAABq-f8ItevgGBFB9aYfl8iwXM_Rb2nxV7hEUwYUPynXbTLg6f_geH1_U1RbPIqp1r; userid=305500613; _ga_14F924BYNN=GS1.1.1705938929.1.1.1705938939.50.0.0; _hc.v=ef39627a-1e47-b3be-bfc0-d56e0ea30a54.1705938940; _ga=GA1.2.1394842790.1705938929; _lxsdk_s=18d31e24038-878-472-bf9|305500613|22"""
cookies_dict = {}
for cookie in cookies_str.split('; '):
    key, value = cookie.split('=')
    cookies_dict[key] = value

# %%
import requests

# 假设我们的网页url是'http://www.example.com'
url = 'https://minsu.dianping.com/yangzhou/?dateBegin=20240123&dateEnd=20240124' 
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-CN,zh;q=0.9",
    "Connection": "keep-alive",
}

response = requests.get(url, cookies=cookies_dict, headers=headers)
print(response.status_code)
# Out:
# 200

# %%
response.text  # 再加代理 ip 是不是就可以了?
# Out:
# '<!Doctype html>\n<html class="">\n<head>\n  <!--[if lte IE 10]><meta http-equiv="refresh" content="0; url=/deprecated.html"><![endif]-->\n  <meta charset="utf-8">\n  <title>扬州民宿_扬州租房_扬州短租-美团民宿</title>\n  <meta http-equiv="x-ua-compatible" content="ie=edge"><meta name="viewport" content="width=device-width,initial-scale=1,user-scalable=no,maximum-scale=1.0"><meta name="renderer" content="webkit"><script src="https://s3plus.meituan.net/v1/mss_28a77f134e5b4abf876b4ff035f4107f/iconfont/project/114/0.0.37/phx_c.js"></script><link href="//s3.meituan.net" rel="dns-prefetch"><link href="//s3-img.meituan.net" rel="dns-prefetch"><link href="//s3plus.meituan.net" rel="dns-prefetch"><link href="//p0.meituan.net" rel="dns-prefetch"><link href="//p1.meituan.net" rel="dns-prefetch"><link href="//img.meituan.net" rel="dns-prefetch">    <meta name="description" content="美团民宿，提供扬州高性价比民宿、短租房、日租房、短租公寓、家庭旅馆等租房信息，服务于扬州民宿房客、房东，你可以查询扬州民宿价格、扬州周边民宿推荐，也可以发布民宿信息。扬州民宿推荐，你的旅程值得住得不一样！美团民宿等你来">\n    <meta name="ke
# ...

# %%
## 试一试呗, 看看什么时候会过期? 过期原因是什么
